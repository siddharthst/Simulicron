# %%
# Imports
import numpy as np
import pandas as pd
import statsmodels.api as sm
from scipy.stats import linregress
from scipy.stats import chisquare
from scipy import stats

# import altair as alt
import seaborn as sns
import matplotlib.pyplot as plt
from itertools import chain, repeat
import pickle
import re
from math import exp, log

# Set Seaborn style
sns.set(style="whitegrid")
plt.style.use("ggplot")
sns.set_context("talk")
# %matplotlib inline

# %%
# Set up the figure
f, (ax1, ax2, ax3) = plt.subplots(1, 3, sharey=True)

# %% [markdown]
# ### u = 1.0

# %%
# Load file from the pickle
fileName = "K1.pickle"
with open(fileName, "rb") as f:
    result = pickle.load(f)

# %%
# Plot the average copy number
plt.figure(figsize=(12, 12))
for i in result:
    f = sns.lineplot(
        x=np.arange(len(i["AvgCopyNum"])), y=i["AvgCopyNum"], color="grey",
    ).set_title(
        "Population Size: 100; Selection coefficient: 0, u:1.0"
    )
plt.ylabel('Avg. copy number', fontsize=18)
plt.xlabel('Generation', fontsize=18)
# Out:
# Text(0.5, 0, 'Generation')

# %% [markdown]
# ### u = 0.1

# %%
# Load file from the pickle
fileName = "K1U010.pickle"
with open(fileName, "rb") as f:
    result = pickle.load(f)

# %%
# Plot the average copy number
plt.figure(figsize=(12, 12))
for i in result:
    sns.lineplot(
        x=np.arange(len(i["AvgCopyNum"])), y=i["AvgCopyNum"], color="grey"
    ).set_title(
        "Population Size: 100; Selection coefficient: 0, u:0.10"
    )
plt.ylabel('Avg. copy number', fontsize=18)
plt.xlabel('Generation', fontsize=18)
# Out:
# Text(0.5, 0, 'Generation')

# %% [markdown]
# ### u = 0.01

# %%
# Load file from the pickle
fileName = "K1U001.pickle"
with open(fileName, "rb") as f:
    result = pickle.load(f)

# %%
# Plot the average copy number
plt.figure(figsize=(12, 12))
for i in result:
    sns.lineplot(x=np.arange(len(i["AvgCopyNum"])), y=i["AvgCopyNum"], color="grey").set_title(
        "Population Size: 100; Selection coefficient: 0, u:0.01"
    )
plt.ylabel('Avg. copy number', fontsize=18)
plt.xlabel('Generation', fontsize=18)
# Out:
# Text(0.5, 0, 'Generation')
